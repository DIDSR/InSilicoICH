# %%
import pandas as pd
from pathlib import *

from classify_module import *

df = pd.read_csv('MASTER_DATASET.csv')

dataset = "Hssayeni"

if dataset == "Hssayeni":
    path = Path('/home/jayse.weaver/computed-tomography-images-for-intracranial-hemorrhage-detection-and-segmentation-1.3.1/')
    img_dir = path / "ct_scans"
    truth_dir = path / "masks"

df_trunc = df.loc[df['Dataset'] == dataset]

subjects = list(df_trunc['Data_ID'].drop_duplicates())

study_viewer(df_trunc, img_dir, truth_dir)
# Out:
# interactive(children=(Dropdown(description='id', options=('049.nii', '050.nii', '051.nii', '052.nii', '053.nii…
