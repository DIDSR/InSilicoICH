# %%
import matplotlib.pyplot as plt
from insilicoICH.ground_truth_definition import phantoms

f, axs = plt.subplots(2, len(phantoms.nihpd_ages), gridspec_kw=dict(wspace=0, hspace=0), figsize=(8, 3), dpi=300)
disp = dict(cmap='gray')

slice_idx = 50 # orig 100

for idx, age in enumerate(phantoms.nihpd_ages):
    phantom = phantoms.load_phantom(age)
    skull = phantom.get_skull_map()
    axs[0, idx].imshow(skull[slice_idx], **disp)
    axs[1, idx].imshow(skull.sum(axis=1), **disp)
    axs[0, idx].set_title(f'{age} years')
    axs[0, idx].set_axis_off()
    axs[1, idx].set_axis_off()
plt.show()
# %%
f, axs = plt.subplots(2, len(phantoms.nihpd_ages), gridspec_kw=dict(wspace=0, hspace=0), figsize=(8, 3), dpi=300)
disp = dict(cmap='gray')

for idx, age in enumerate(phantoms.nihpd_ages):
    phantom = phantoms.load_phantom(age)
    skull = phantom.get_skull_map_old()
    axs[0, idx].imshow(skull[slice_idx], **disp)
    axs[1, idx].imshow(skull.sum(axis=1), **disp)
    axs[0, idx].set_title(f'{age} years')
    axs[0, idx].set_axis_off()
    axs[1, idx].set_axis_off()
plt.show()
# %%
f, axs = plt.subplots(2, 1, dpi=300)
disp = dict(cmap='gray')
age = 38
phantom = phantoms.load_phantom(age)
skull = phantom.get_skull_map()
axs[0].imshow(skull[200], **disp)
axs[1].imshow(skull.sum(axis=1), **disp)
axs[0].set_title(f'{age} years')
axs[0].set_axis_off()
axs[1].set_axis_off()
